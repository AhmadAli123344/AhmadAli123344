# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv('Churn_Modelling.csv')
df=df.drop('RowNumber',axis=1)

plt.figure(1)
sns.countplot(data=df,x=df.Geography,hue='Gender')

plt.figure(2)
sns.countplot(data=df,x=df.Exited,hue='Gender')

from sklearn.preprocessing import LabelEncoder
lab=LabelEncoder()
df['Surname']=lab.fit_transform(df['Surname'])
df['Geography']=lab.fit_transform(df['Geography'])
df['Gender']=lab.fit_transform(df['Gender'])

from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X=df.drop('Exited',axis=1)
y=df['Exited']

X1=scaler.fit_transform(X)
print('Scaled X1:- \n',X1)
df
# Out:
# Scaled X1:-
#  [[-0.78321342 -0.46418322 -0.32622142 ...  0.64609167  0.97024255
#    0.02188649]
#  [-0.60653412 -0.3909112  -0.44003595 ... -1.54776799  0.97024255
#    0.21653375]
#  [-0.99588476  0.62898807 -1.53679418 ...  0.64609167 -1.03067011
#    0.2406869 ]
#  ...
#  [-1.47928179  0.07353887  0.60498839 ... -1.54776799  0.97024255
#   -1.00864308]
#  [-0.11935577  0.98943914  1.25683526 ...  0.64609167 -1.03067011
#   -0.12523071]
#  [-0.87055909  1.4692527   1.46377078 ...  0.64609167 -1.03067011
#   -1.07636976]]
#       CustomerId  Surname  CreditScore  Geography  Gender  Age  Tenure  \
# 0       15634602     1115          619          0       0   42       2
# 1       15647311     1177          608          2       0   41       1
# 2       15619304     2040          502          0       0   42       8
# 3       15701354      289          699          0       0   39       1
# 4       15737888     1822          850          2       0   43       2
# ...

# %%
import pickle
with open("Preprocess_variables.pkl", "wb") as f:
    pickle.dump((X1,y), f)
