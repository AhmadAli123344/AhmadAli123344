# %% [markdown]
# # Assignment 01-C1-04-13-06-2023
# # Ahmad Ali

# %% [markdown]
# # Task 1

# %%
import pandas as pd
df1=pd.read_excel('Sample_Superstore.xls',sheet_name='Orders')

# %%
df1.duplicated() # Check Duplicate rows
df1.drop_duplicates(inplace = True)  # Remove Duplicate Rows

# %%
df1.fillna(0,inplace=True)  # Fill NaN values with 0

# %%
df1.columns.duplicated() # Check Duplicate Columns
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False])

# %%
df1
# Out:
#        Row ID        Order ID           Order Date            Ship Date  \
# 0         1.0  CA-2016-152156  2016-11-08 00:00:00  2016-11-11 00:00:00
# 1         2.0  CA-2016-152156  2016-11-08 00:00:00  2016-11-11 00:00:00
# 2         3.0  CA-2016-138688  2016-06-12 00:00:00  2016-06-16 00:00:00
# 3         4.0  US-2015-108966  2015-10-11 00:00:00  2015-10-18 00:00:00
# 4         5.0  US-2015-108966  2015-10-11 00:00:00  2015-10-18 00:00:00
# ...       ...             ...                  ...                  ...
# 11415  9980.0  US-2016-103674  2016-12-06 00:00:00  2016-12-10 00:00:00
# 11416  9981.0  US-2015-151435  2015-09-06 00:00:00  2015-09-09 00:00:00
# 11417  9982.0  CA-2017-163566  2017-08-03 00:00:00  2017-08-06 00:00:00
# 11418  9983.0  US-2016-157728  2016-09-22 00:00:00  2016-09-28 00:00:00
# 11419  9984.0  US-2016-157728  2016-09-22 00:00:00  2016-09-28 00:00:00
#
#             Ship Mode Customer ID    Customer Name      Segment  \
# ...

# %% [markdown]
# # Task 2

# %%
df1.sort_values('Profit.1',ascending=False)[['Order Date','Profit.1']].head(1)
# Out:
#                Order Date  Profit.1
# 6826  2016-10-02 00:00:00  8399.976

# %% [markdown]
# # Task 3

# %%
b=df1.groupby('State')['Sales'].mean()
b
# Out:
# State
# 0                          0.000000
# Alabama                  308.574844
# Arizona                  151.143224
# Arkansas                 221.123710
# California               231.220057
# Colorado                 168.818168
# Connecticut              160.225943
# Delaware                 262.923173
# District of Columbia      27.832857
# Florida                  222.605841
# Georgia                  257.549550
# Idaho                    210.268667
# Illinois                 159.018820
# Indiana                  343.774651
# Iowa                     133.825429
# Kansas                   121.429583
# Kentucky                 279.690000
# Louisiana                232.291915
# Maine                    171.604545
# Maryland                 213.927219
# Massachusetts            215.781369
# Michigan                 310.400550
# Minnesota                327.102737
# Mississippi              199.539273
# Missouri                 398.180533
# Montana                  372.623467
# ...

# %% [markdown]
# # Task 4

# %%
df1.sort_values('Profit.1',ascending=True)[['Order Date','Customer ID','Customer Name','Profit.1']].head(1)
# Out:
#                Order Date Customer ID  Customer Name  Profit.1
# 7772  2016-11-25 00:00:00    CS-12505  Cindy Stewart -6599.978

# %% [markdown]
# # Task 5

# %%
a=df1['Ship Mode'].value_counts()
b=pd.DataFrame(a)
b.head(1)
# Out:
#                 Ship Mode
# Standard Class       6694

# %% [markdown]
# # Task 6

# %%
a=df1[df1['State']=="Arizona"]
a.sort_values('Profit.1',ascending=False)[['Customer Name','Profit.1','State']].head(1)
# Out:
#      Customer Name  Profit.1    State
# 2548   John Murray  211.4955  Arizona

# %% [markdown]
# # Task 7

# %%
df1.sort_values('Profit.1',ascending=False)[['State','Profit.1']].head(1)
# Out:
#         State  Profit.1
# 6826  Indiana  8399.976

# %% [markdown]
# # Task 8

# %%
df1.sort_values('Sales',ascending=False)[['Category','Sales']].head(1)
# Out:
#         Category     Sales
# 2697  Technology  22638.48
